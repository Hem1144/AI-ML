# %% [markdown]
# <a href="https://colab.research.google.com/github/Hem1144/AI-ML/blob/ml-core/UnivariateAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/ml-datasts/train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 773          774         0       3
# 532          533         0       3
# 674          675         0       2
# 187          188         1       1
# 316          317         1       2
#
#                                               Name     Sex   Age  SibSp  \
# 773                                Elias, Mr. Dibo    male   NaN      0
# 532                           Elias, Mr. Joseph Jr    male  17.0      1
# 674                     Watson, Mr. Ennis Hastings    male   NaN      0
# 187  Romaine, Mr. Charles Hallace ("Mr C Rolmane")    male  45.0      0
# 316            Kantor, Mrs. Sinai (Miriam Sternin)  female  24.0      1
#
#      Parch  Ticket     Fare Cabin Embarked
# 773      0    2674   7.2250   NaN        C
# 532      1    2690   7.2292   NaN        C
# 674      0  239856   0.0000   NaN        S
# 187      0  111428  26.5500   NaN        S
# 316      0  244367  26.0000   NaN        S

# %% [markdown]
# **Categorical Data**

# %%
# sns.countplot(df['Survived'])
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Numerical Data**

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'], bins=20)
# Out:
# (array([40., 14., 15., 31., 79., 98., 85., 84., 73., 45., 35., 35., 29.,
#         16., 13., 11.,  4.,  5.,  1.,  1.]),
#  array([ 0.42 ,  4.399,  8.378, 12.357, 16.336, 20.315, 24.294, 28.273,
#         32.252, 36.231, 40.21 , 44.189, 48.168, 52.147, 56.126, 60.105,
#         64.084, 68.063, 72.042, 76.021, 80.   ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# **Distplot**

# %%
sns.distplot(df['Age'])
# Out:
# /tmp/ipython-input-3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# **Boxplot**

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)
